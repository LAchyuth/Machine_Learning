# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv("D:\Learnbay\ML Real Time Project\HR Analytics\Attrition.csv")
data.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
data.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
# Descriptive Analytics

data.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
# checking correlation 
pd.set_option('display.max_columns',None)
correlation = data.corr()

# %%
plt.figure(figsize = (20,16))
sns.heatmap(data.corr(),annot=True,cmap = 'coolwarm')
plt.show()

# %%
data.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
data['Attrition'].value_counts()
# Out:
# No     1233
# Yes     237
# Name: Attrition, dtype: int64

# %%
data['Attrition'].value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.title('Attrition Percentage')
# Out:
# Text(0.5, 1.0, 'Attrition Percentage')

# %%
# Analyse Age vs Attrition
sns.distplot(data[data["Attrition"]=='No']['Age'],hist = False,label = 'No',color = 'black')
sns.distplot(data[data["Attrition"]=='Yes']['Age'],hist = False,label = 'Yes',color = 'red')
plt.title("Relation between Age and Attrition of the Employee")
# Out:
# Text(0.5, 1.0, 'Relation between Age and Attrition of the Employee')

# %%
department = pd.crosstab(data['Department'],data['Attrition'])
department['Total'] = department['No'] + department['Yes']
department['Percentage'] =  department['Yes']/department['Total']
department
# Out:
# Attrition                No  Yes  Total  Percentage
# Department
# Human Resources          51   12     63    0.190476
# Research & Development  828  133    961    0.138398
# Sales                   354   92    446    0.206278

# %%
# Analyse Age vs Attrition
sns.distplot(data[data["Attrition"]=='No']['PercentSalaryHike'],hist = False,label = 'No',color = 'black')
sns.distplot(data[data["Attrition"]=='Yes']['PercentSalaryHike'],hist = False,label = 'Yes',color = 'red')
plt.title("Relation between PercentSalaryHike and Attrition of the Employee")
# Out:
# Text(0.5, 1.0, 'Relation between PercentSalaryHike and Attrition of the Employee')

# %%
gender_wise = pd.crosstab(data['Gender'], data['Attrition'])
gender_wise.plot(kind = 'bar')
plt.title("Gender vs Attrition")
# Out:
# Text(0.5, 1.0, 'Gender vs Attrition')

# %%
data['Gender'].value_counts()
# Out:
# Male      882
# Female    588
# Name: Gender, dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le =LabelEncoder()

data['Attrition'] = le.fit_transform(data['Attrition'])
data['BusinessTravel'] = le.fit_transform(data['BusinessTravel'])
data['Department'] = le.fit_transform(data['Department'])
data['EducationField'] = le.fit_transform(data['EducationField'])
data['Gender'] = le.fit_transform(data['Gender'])
data['JobRole'] = le.fit_transform(data['JobRole'])
data['Over18'] = le.fit_transform(data['Over18'])
data['OverTime'] = le.fit_transform(data['OverTime'])
data['MaritalStatus'] = le.fit_transform(data['MaritalStatus'])

# %%
data.head()
# Out:
#    Age  Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0   41          1               2       1102           2                 1
# 1   49          0               1        279           1                 8
# 2   37          1               2       1373           1                 2
# 3   33          0               1       1392           1                 3
# 4   27          0               2        591           1                 2
#
#    Education  EducationField  EmployeeCount  EmployeeNumber  \
# 0          2               1              1               1
# 1          1               1              1               2
# 2          2               4              1               4
# 3          4               1              1               5
# 4          1               3              1               7
#
#    EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# 0                        2       0          94               3         2
# ...

# %%
x = data.drop(['Attrition'],axis =1)
y =data['Attrition']

# %%
x.head()
# Out:
#    Age  BusinessTravel  DailyRate  Department  DistanceFromHome  Education  \
# 0   41               2       1102           2                 1          2
# 1   49               1        279           1                 8          1
# 2   37               2       1373           1                 2          2
# 3   33               1       1392           1                 3          4
# 4   27               2        591           1                 2          1
#
#    EducationField  EmployeeCount  EmployeeNumber  EnvironmentSatisfaction  \
# 0               1              1               1                        2
# 1               1              1               2                        3
# 2               4              1               4                        4
# 3               1              1               5                        4
# 4               3              1               7                        1
#
# ...

# %%
y.head()
# Out:
# 0    1
# 1    0
# 2    1
# 3    0
# 4    0
# Name: Attrition, dtype: int32

# %%
y.value_counts()
# Out:
# 0    1233
# 1     237
# Name: Attrition, dtype: int64

# %%
import imblearn
from imblearn.over_sampling import SMOTE
smote = SMOTE()
x_smote, y_smote = smote.fit_resample(x,y)
print(y.value_counts())
print()
print(y_smote.value_counts())
# Out:
# 0    1233
# 1     237
# Name: Attrition, dtype: int64
#
# 1    1233
# 0    1233
# Name: Attrition, dtype: int64

# %%
plt.figure(figsize = (20,16))
sns.heatmap(data.corr(),annot=True,cmap = 'coolwarm')
plt.show()

# %%
# split the data into training and test
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test =train_test_split(x_smote,y_smote,test_size =0.25,random_state =101)

# %% [markdown]
# ## RandomForestClassifier

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier()
rf.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred_train = rf.predict(x_train)
y_pred_test = rf.predict(x_test)

# %%
from sklearn.metrics import classification_report,accuracy_score,confusion_matrix

# %%
print(classification_report(y_train,y_pred_train))
print("**********************"*5)
print(classification_report(y_test,y_pred_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       915
#            1       1.00      1.00      1.00       934
#
#     accuracy                           1.00      1849
#    macro avg       1.00      1.00      1.00      1849
# weighted avg       1.00      1.00      1.00      1849
#
# **************************************************************************************************************
#               precision    recall  f1-score   support
#
#            0       0.90      0.92      0.91       318
#            1       0.91      0.90      0.91       299
#
#     accuracy                           0.91       617
#    macro avg       0.91      0.91      0.91       617
# weighted avg       0.91      0.91      0.91       617

# %%
print(accuracy_score(y_train,y_pred_train))
print("**********************"*5)
print(accuracy_score(y_test,y_pred_test))
# Out:
# 1.0
# **************************************************************************************************************
# 0.9092382495948136

# %%
print(confusion_matrix(y_train,y_pred_train))
print("**********************"*5)
print(confusion_matrix(y_test,y_pred_test))
# Out:
# [[915   0]
#  [  0 934]]
# **************************************************************************************************************
# [[293  25]
#  [ 31 268]]

# %% [markdown]
# ## Cross-Validation

# %%
from sklearn.model_selection import cross_val_score

# %%
training_accuracy = cross_val_score(rf,x_train,y_train,cv =10)
print("Average Accuracy:",training_accuracy.mean())
print("Max Accuracy:",training_accuracy.max())
print("Min Accuracy:",training_accuracy.min())
# Out:
# Average Accuracy: 0.9183460634547591
# Max Accuracy: 0.9459459459459459
# Min Accuracy: 0.8864864864864865

# %% [markdown]
# ## Grid SearchCV

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid = {'n_estimators': [50, 100], 'criterion': ['gini', 'entropy'],
              'max_depth': [5, 10], 'min_samples_split': [2, 5],
              'min_samples_leaf': [1, 2, 3], 'bootstrap': [True, False]}

grid_search = GridSearchCV(estimator=RandomForestClassifier(), param_grid=param_grid, cv=6)
grid_search.fit(x_train, y_train)

best_params = grid_search.best_params_
print(best_params)
best_score = grid_search.best_score_
print(best_score)
best_model = grid_search.best_estimator_
print(best_model)
# Out:
# {'bootstrap': False, 'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 50}
# 0.9004731783857998
# RandomForestClassifier(bootstrap=False, max_depth=10, min_samples_leaf=2,
#                        n_estimators=50)

# %%
best_params = grid_search.best_params_
best_score = grid_search.best_score_

# %%
best_model = grid_search.best_estimator_

# %%
y_pred = best_model.predict(x_test)

# %%
importances = rf.feature_importances_

# %%
importances
# Out:
# array([0.03642724, 0.0286437 , 0.04337056, 0.00791133, 0.03961713,
#        0.02416168, 0.01911283, 0.        , 0.04186621, 0.0421485 ,
#        0.00867456, 0.03683004, 0.05031792, 0.03431844, 0.01888042,
#        0.05352174, 0.01825092, 0.05900315, 0.04024451, 0.01965102,
#        0.        , 0.00994732, 0.02140883, 0.00760658, 0.04002006,
#        0.        , 0.0714337 , 0.03273617, 0.03252748, 0.02732044,
#        0.03337176, 0.03832719, 0.02394554, 0.03840303])

# %%
x.columns
# Out:
# Index(['Age', 'BusinessTravel', 'DailyRate', 'Department', 'DistanceFromHome',
#        'Education', 'EducationField', 'EmployeeCount', 'EmployeeNumber',
#        'EnvironmentSatisfaction', 'Gender', 'HourlyRate', 'JobInvolvement',
#        'JobLevel', 'JobRole', 'JobSatisfaction', 'MaritalStatus',
#        'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'Over18',
#        'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
imp_features = pd.DataFrame({'Featues':x.columns,'Feature_importance':importances})
imp_features.sort_values(by = 'Feature_importance',ascending =False,inplace =True)

# %%
imp_features
# Out:
#                      Featues  Feature_importance
# 26          StockOptionLevel            0.071434
# 17             MonthlyIncome            0.059003
# 15           JobSatisfaction            0.053522
# 12            JobInvolvement            0.050318
# 2                  DailyRate            0.043371
# 9    EnvironmentSatisfaction            0.042149
# 8             EmployeeNumber            0.041866
# 18               MonthlyRate            0.040245
# 24  RelationshipSatisfaction            0.040020
# 4           DistanceFromHome            0.039617
# 33      YearsWithCurrManager            0.038403
# 31        YearsInCurrentRole            0.038327
# 11                HourlyRate            0.036830
# 0                        Age            0.036427
# 13                  JobLevel            0.034318
# 30            YearsAtCompany            0.033372
# 27         TotalWorkingYears            0.032736
# 28     TrainingTimesLastYear            0.032527
# ...

# %%
indices = np.argsort(importances)[::-1]
sorted_importances = importances[indices]
sorted_features = [x[i] for i in indices]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 26
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %% [markdown]
# ## Random Seach CV

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
param_rand = {'n_estimators': [50, 100], 'criterion': ['gini', 'entropy'],
              'max_depth': [5, 10], 'min_samples_split': [2, 5],
              'min_samples_leaf': [1, 2, 3], 'bootstrap': [True, False]}
random_search = RandomizedSearchCV(estimator =rf, param_distributions= param_rand,
                                   n_iter=25,cv =6,random_state = 1)
random_search.fit(x_train,y_train)
# Out:
# RandomizedSearchCV(cv=6, estimator=RandomForestClassifier(), n_iter=25,
#                    param_distributions={'bootstrap': [True, False],
#                                         'criterion': ['gini', 'entropy'],
#                                         'max_depth': [5, 10],
#                                         'min_samples_leaf': [1, 2, 3],
#                                         'min_samples_split': [2, 5],
#                                         'n_estimators': [50, 100]},
#                    random_state=1)

# %%
best_param = random_search.best_params_
best_scores = random_search.best_score_
print("Best Parameters:",best_param)
print()
print("Best Scores:",best_scores)
# Out:
# Best Parameters: {'n_estimators': 100, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_depth': 10, 'criterion': 'entropy', 'bootstrap': False}
#
# Best Scores: 0.904262808389022

# %%
best_model = random_search.best_estimator_
print(best_model)
# Out:
# RandomForestClassifier(bootstrap=False, criterion='entropy', max_depth=10)

# %% [markdown]
# ### Model Building again with One Hot Encoding method to compare the performance

# %%
data1 = pd.read_csv("D:\Learnbay\ML Real Time Project\HR Analytics\Attrition.csv")
data1.head()

# %%
data1.info()

# %%
data1.shape

# %%
data2 = pd.get_dummies(data1, columns = ['BusinessTravel','Department','EducationField',
                                       'Gender','JobRole','MaritalStatus','Over18','OverTime' ])

# %%
data2['Attrition'] = data2['Attrition'].astype('category')
data2['Attrition'] = data2['Attrition'].cat.codes

# %%
data2.shape

# %%
x = data2.drop(['Attrition'],axis =1)
y = data2['Attrition']

# %%
import imblearn
from imblearn.over_sampling import SMOTE
smote = SMOTE()

x_smote,y_smote = smote.fit_resample(x,y)

# %%
print(y.value_counts())
print()
print(y_smote.value_counts())

# %%
# split the data into training and test
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test =train_test_split(x_smote,y_smote,test_size =0.25,random_state =101)

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier()
rf.fit(x_train,y_train)

# %%
y_pred_rf_xtrain = rf.predict(x_train)
y_pred_rf_xtest = rf.predict(x_test)

# %%
print(classification_report(y_train,y_pred_rf_xtrain))
print()
print(classification_report(y_test,y_pred_rf_xtest))

# %%
print("Training Accuracy:",accuracy_score(y_train,y_pred_rf_xtrain))
print()
print("Test Accuracy:",accuracy_score(y_test,y_pred_rf_xtest))

# %%
print(confusion_matrix(y_train,y_pred_rf_xtrain))
print()
print(confusion_matrix(y_test,y_pred_rf_xtest))

# %%
Training_Accuracy = cross_val_score(rf,x_train,y_train)
print(Training_Accuracy.mean())
print(Training_Accuracy.max())
print(Training_Accuracy.min())
